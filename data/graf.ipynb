# %%
import pandas as pd
import streamlit as st

# %%
df = pd.read_csv('totcat-centres-educatius.csv', sep=';', encoding='latin1')
df = df.loc[df['Nom_localitat'] == 'Barcelona']
df.head()
# Out:
#     Codi_centre            Denominació_completa  Codi_naturalesa  \
# 47      8001595                 Escola Baixeras                1
# 48      8001601    Escola Parc de la Ciutadella                1
# 49      8001649  Escola Mossèn Jacint Verdaguer                1
# 50      8001650               Escola El Polvorí                1
# 51      8001674                 Escola Can Clos                1
#
#    Nom_naturalesa  Codi_titularitat  \
# 47         Públic                 1
# 48         Públic                 1
# 49         Públic                 1
# 50         Públic                 1
# 51         Públic                 1
#
#                                    Nom_titularitat  \
# 47  Departament d'Educació i Formació Professional
# 48  Departament d'Educació i Formació Professional
# 49  Departament d'Educació i Formació Professional
# 50  Departament d'Educació i Formació Professional
# 51  Departament d'Educació i Formació Professional
#
# ...

# %%
df.columns
# Out:
# Index(['Codi_centre', 'Denominació_completa', 'Codi_naturalesa',
#        'Nom_naturalesa', 'Codi_titularitat', 'Nom_titularitat', 'Adreça',
#        'Codi_postal', 'Telèfon', 'Codi_delegació', 'Nom_delegació',
#        'Codi_comarca', 'Nom_comarca', 'Codi_municipi', 'Nom_municipi',
#        'Codi_districte_municipal', 'Nom_DM', 'Codi_localitat', 'Nom_localitat',
#        'Zona_educativa', 'Coordenades_UTM_X', 'Coordenades_UTM_Y',
#        'Coordenades_GEO_X', 'Coordenades_GEO_Y', 'E-mail_centre', 'Estudis',
#        'EINF1C', 'EINF2C', 'EPRI', 'ESO', 'BATX', 'AA01', 'CFPM', 'PPAS',
#        'AA03', 'CFPS', 'EE', 'IFE', 'PFI', 'PA01', 'CFAM', 'PA02', 'CFAS',
#        'ESDI', 'ESCM', 'ESCS', 'ADR', 'CRBC', 'IDI', 'DANE', 'DANP', 'DANS',
#        'MUSE', 'MUSP', 'MUSS', 'TEGM', 'TEGS', 'ESTR', 'ADULTS'],
#       dtype='object')

# %%
df = df[["Codi_centre", "Denominació_completa", "Coordenades_GEO_X", "Coordenades_GEO_Y"]]
df.head()
# Out:
#     Codi_centre            Denominació_completa Coordenades_GEO_X  \
# 47      8001595                 Escola Baixeras          2,179781
# 48      8001601    Escola Parc de la Ciutadella          2,187829
# 49      8001649  Escola Mossèn Jacint Verdaguer          2,154765
# 50      8001650               Escola El Polvorí          2,143079
# 51      8001674                 Escola Can Clos           2,14755
#
#    Coordenades_GEO_Y
# 47          41,38283
# 48          41,38484
# 49          41,37336
# 50          41,36324
# 51          41,36075

# %%
st.map(df)
